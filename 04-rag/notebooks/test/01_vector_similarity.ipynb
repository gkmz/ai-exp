# %%
from pathlib import Path
import sys

# 让 Notebook 可以导入项目中的 src 包。
project_root = Path.cwd().parent
print(project_root)
sys.path.insert(0, str(project_root / "src"))

from rag_study.experiments.vector_similarity import (
    cosine_similarity,
    dot_product,
    euclidean_distance,
)
# Out:
# /Users/hank/workspace/mine/ai-exp/04-rag/notebooks
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 9
#       5 project_root = Path.cwd().parent
#       6 print(project_root)
#       7 sys.path.insert(0, str(project_root / "src"))
#       8
# ----> 9 from rag_study.experiments.vector_similarity import (
#      10     cosine_similarity,
#      11     dot_product,
#      12     euclidean_distance,
#
# ModuleNotFoundError: No module named 'rag_study'
